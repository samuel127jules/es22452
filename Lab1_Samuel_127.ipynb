# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel127jules/es22452/blob/main/Lab1_Samuel_127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from types import MethodDescriptorType
depth_ft = 3500
conversion_factor = 0.3048
depth_m = depth_ft * conversion_factor
print(depth_m)
print(f"The borehole depth is {depth_m} meters")
print("The borehole depth is "+str(depth_m)+" meters")
# Out:
# 1066.8
# The borehole depth is 1066.8 meters
# The borehole depth is 1066.8 meters

# %%
magnitudes = [2.4, 3.1, 1.8, 4.5, 2.9, 0.5, 3.3]
print(magnitudes[0])
print(magnitudes[-1])
magnitudes.append(5.1)
print(len(magnitudes))
print(magnitudes)
# Out:
# 2.4
# 3.3
# 8
# [2.4, 3.1, 1.8, 4.5, 2.9, 0.5, 3.3, 5.1]

# %%
total_magnitude = 0
for magnitude in magnitudes:
  total_magnitude = total_magnitude + magnitude
  print(total_magnitude)
# Out:
# 2.4
# 5.5
# 7.3
# 11.8
# 14.700000000000001
# 15.200000000000001
# 18.5
# 23.6

# %%
print(total_magnitude/len(magnitudes))
# Out:
# 2.95

# %%
magnitude < 3.0
magnitude >= 3.0

for mag in magnitudes:
  if mag < 3.0:
    print("For Micro earthquake " +str(mag))
  else:
    print("For Minor earthquake " +str(mag))
# Out:
# For Micro earthquake 2.4
# For Minor earthquake 3.1
# For Micro earthquake 1.8
# For Minor earthquake 4.5
# For Micro earthquake 2.9
# For Micro earthquake 0.5
# For Minor earthquake 3.3
# For Minor earthquake 5.1

# %%
depths = [0, 1, 2, 3, 4, 5]
temperatures = []

surface_temp = 15
gradient = 25

for i in range(0,len(depths)):
  temperatures.append(surface_temp + gradient * depths[i])
print(temperatures)
# Out:
# [15, 40, 65, 90, 115, 140]
